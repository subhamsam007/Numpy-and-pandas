# %% [markdown]
# <a href="https://colab.research.google.com/github/subhamsam007/Numpy-and-pandas/blob/main/IPL_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Loading the Libraries and Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('IPL.csv')
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %% [markdown]
# # Basic Information

# %%
df.columns
# Out:
# Index(['match_id', 'date', 'venue', 'team1', 'team2', 'stage', 'toss_winner',
#        'toss_decision', 'first_ings_score', 'first_ings_wkts',
#        'second_ings_score', 'second_ings_wkts', 'match_winner', 'won_by',
#        'margin', 'player_of_the_match', 'top_scorer', 'highscore',
#        'best_bowling', 'best_bowling_figure'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   match_id             74 non-null     int64
#  1   date                 74 non-null     object
#  2   venue                74 non-null     object
#  3   team1                74 non-null     object
#  4   team2                74 non-null     object
#  5   stage                74 non-null     object
#  6   toss_winner          74 non-null     object
#  7   toss_decision        74 non-null     object
#  8   first_ings_score     74 non-null     int64
#  9   first_ings_wkts      74 non-null     int64
#  10  second_ings_score    74 non-null     int64
#  11  second_ings_wkts     74 non-null     int64
#  12  match_winner         74 non-null     object
#  13  won_by               74 non-null     object
#  14  margin               74 non-null     int64
# ...

# %% [markdown]
# **Check the size of rows and columns of the dataset**

# %%
print(f"your rows are {df.shape[0]} and your columns are {df.shape[1]}")
# Out:
# your rows are 74 and your columns are 20

# %%
df.shape
# Out:
# (74, 20)

# %% [markdown]
# **Now let's see how many columns have null values in total.**

# %%
df.isnull().sum()
# Out:
# match_id               0
# date                   0
# venue                  0
# team1                  0
# team2                  0
# stage                  0
# toss_winner            0
# toss_decision          0
# first_ings_score       0
# first_ings_wkts        0
# second_ings_score      0
# second_ings_wkts       0
# match_winner           0
# won_by                 0
# margin                 0
# player_of_the_match    0
# top_scorer             0
# highscore              0
# best_bowling           0
# best_bowling_figure    0
# dtype: int64

# %% [markdown]
# Here comes some Basic Questions

# %% [markdown]
# **1. Which team won the most matches?**

# %%
df.columns # to check the coloum so i can see what are the coloum are present
# Out:
# Index(['match_id', 'date', 'venue', 'team1', 'team2', 'stage', 'toss_winner',
#        'toss_decision', 'first_ings_score', 'first_ings_wkts',
#        'second_ings_score', 'second_ings_wkts', 'match_winner', 'won_by',
#        'margin', 'player_of_the_match', 'top_scorer', 'highscore',
#        'best_bowling', 'best_bowling_figure'],
#       dtype='object')

# %%
most_matches_won = df['match_winner'].value_counts()

# %%
sns.barplot(x=most_matches_won.values,y=most_matches_won.index,palette= "Spectral")
plt.xlabel('Number of Matches Won')
plt.ylabel('Team')
plt.title('Matches Won by Each Team')
# Out:
# /tmp/ipykernel_12930/309189431.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=most_matches_won.values,y=most_matches_won.index,palette= "Spectral")
# Text(0.5, 1.0, 'Matches Won by Each Team')

# %% [markdown]
# **2. Toss Decision Trends**

# %%
sns.countplot(x=df['toss_decision'],hue=df['toss_winner'] , palette='Spectral')
plt.title('Toss Decision')
# Out:
# Text(0.5, 1.0, 'Toss Decision')

# %%
sns.countplot(x=df['toss_decision'],palette='ch:s=.25,rot=-.25')
plt.title
# Out:
# /tmp/ipykernel_12930/2537218241.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['toss_decision'],palette='ch:s=.25,rot=-.25')
# <function matplotlib.pyplot.title(label: 'str', fontdict: 'dict[str, Any] | None' = None, loc: "Literal['left', 'center', 'right'] | None" = None, pad: 'float | None' = None, *, y: 'float | None' = None, **kwargs) -> 'Text'>

# %% [markdown]
# **3.Toss Winner vs Match Winner**

# %%
toss_winner_vs_match_winner =  df[df['toss_winner'] == df['match_winner']]['match_id'].count()

# %%
percetage = (toss_winner_vs_match_winner / df.shape[0]) * 100

# %%
percetage.round(2)  # so 48% won the match who win the match
# Out:
# np.float64(48.65)

# %% [markdown]
# **4. How do teams win? (Runs vs Wickets)**

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
run_wickets = sns.countplot(x=df['won_by'], palette='viridis')
run_wickets.set_title('Runs vs Wickets')
# Out:
# /tmp/ipykernel_12930/1915350211.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   run_wickets = sns.countplot(x=df['won_by'], palette='viridis')
# Text(0.5, 1.0, 'Runs vs Wickets')

# %%
df[df['match_winner'] == df['won_by']]['match_id'].count()
# Out:
# np.int64(0)

# %%
per = (df[df['match_winner'] == df['won_by']]['match_id'] / df.shape[0]) * 100

# %%
per
# Out:
# Series([], Name: match_id, dtype: float64)

# %% [markdown]
# # Key Player Performances

# %% [markdown]
# **1 Most "Player of the Match" Awards**

# %%
df.head(1)
# Out:
#    match_id           date                     venue    team1    team2  stage  \
# 0         1  March 26,2022  Wankhede Stadium, Mumbai  Chennai  Kolkata  Group
#
#   toss_winner toss_decision  first_ings_score  first_ings_wkts  \
# 0     Kolkata         Field               131                5
#
#    second_ings_score  second_ings_wkts match_winner   won_by  margin  \
# 0                133                 4      Kolkata  Wickets       6
#
#   player_of_the_match top_scorer  highscore  best_bowling best_bowling_figure
# 0         Umesh Yadav   MS Dhoni         50  Dwayne Bravo               3--20

# %%
most_player_of_the_match = df['player_of_the_match'].value_counts().head(10)
most_player_of_the_match
# Out:
# player_of_the_match
# Kuldeep Yadav        4
# Jos Buttler          3
# Wanindu Hasaranga    2
# Umesh Yadav          2
# Quinton de Kock      2
# Shubman Gill         2
# Avesh Khan           2
# Dinesh Karthik       2
# Hardik Pandya        2
# Rahul Tripathi       2
# Name: count, dtype: int64

# %%
sns.barplot(x= most_player_of_the_match.values,y= most_player_of_the_match.index,palette= "mako")
plt.title("Top 10 plauers with man of the match")
# Out:
# /tmp/ipykernel_12930/905610325.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x= most_player_of_the_match.values,y= most_player_of_the_match.index,palette= "mako")
# Text(0.5, 1.0, 'Top 10 plauers with man of the match')

# %% [markdown]
# **2 Top Scorers**

# %%
df.head(1)
# Out:
#    match_id           date                     venue    team1    team2  stage  \
# 0         1  March 26,2022  Wankhede Stadium, Mumbai  Chennai  Kolkata  Group
#
#   toss_winner toss_decision  first_ings_score  first_ings_wkts  \
# 0     Kolkata         Field               131                5
#
#    second_ings_score  second_ings_wkts match_winner   won_by  margin  \
# 0                133                 4      Kolkata  Wickets       6
#
#   player_of_the_match top_scorer  highscore  best_bowling best_bowling_figure
# 0         Umesh Yadav   MS Dhoni         50  Dwayne Bravo               3--20

# %%
toop_scorers = df['top_scorer'].value_counts().head(10)

# %%
toop_scorers
# Out:
# top_scorer
# Jos Buttler         7
# Quinton de Kock     5
# Liam Livingstone    4
# Shubman Gill        4
# KL Rahul            4
# Ishan Kishan        3
# David Warner        3
# W. Saha             3
# Faf du Plessis      3
# Shikhar Dhawan      2
# Name: count, dtype: int64

# %%
sns.barplot(x= toop_scorers.values,y= toop_scorers.index,palette= "Spectral")
# Out:
# /tmp/ipykernel_12930/361582902.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x= toop_scorers.values,y= toop_scorers.index,palette= "Spectral")
# <Axes: ylabel='top_scorer'>

# %% [markdown]
# **10 Best Bowling Figures**

# %%
df.columns
# Out:
# Index(['match_id', 'date', 'venue', 'team1', 'team2', 'stage', 'toss_winner',
#        'toss_decision', 'first_ings_score', 'first_ings_wkts',
#        'second_ings_score', 'second_ings_wkts', 'match_winner', 'won_by',
#        'margin', 'player_of_the_match', 'top_scorer', 'highscore',
#        'best_bowling', 'best_bowling_figure'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    match_id           date                     venue    team1    team2  stage  \
# 0         1  March 26,2022  Wankhede Stadium, Mumbai  Chennai  Kolkata  Group
#
#   toss_winner toss_decision  first_ings_score  first_ings_wkts  \
# 0     Kolkata         Field               131                5
#
#    second_ings_score  second_ings_wkts match_winner   won_by  margin  \
# 0                133                 4      Kolkata  Wickets       6
#
#   player_of_the_match top_scorer  highscore  best_bowling best_bowling_figure
# 0         Umesh Yadav   MS Dhoni         50  Dwayne Bravo               3--20

# %%
df['highest_wickets'] = df['best_bowling_figure'].apply(lambda x :x.split('--')[0])
df['highest_wickets'] = df['highest_wickets'].astype(int)
top_bowlers = df.groupby('best_bowling')['highest_wickets'].sum().sort_values(ascending=False).head(10)
top_bowlers.plot(kind = 'barh')
# Out:
# <Axes: ylabel='best_bowling'>

# %%
df.head(1)
# Out:
#    match_id           date                     venue    team1    team2  stage  \
# 0         1  March 26,2022  Wankhede Stadium, Mumbai  Chennai  Kolkata  Group
#
#   toss_winner toss_decision  first_ings_score  first_ings_wkts  ...  \
# 0     Kolkata         Field               131                5  ...
#
#    second_ings_wkts  match_winner   won_by margin  player_of_the_match  \
# 0                 4       Kolkata  Wickets      6          Umesh Yadav
#
#   top_scorer highscore  best_bowling best_bowling_figure highest_wickets
# 0   MS Dhoni        50  Dwayne Bravo               3--20               3
#
# [1 rows x 21 columns]

# %% [markdown]
# # Venue Analysis

# %% [markdown]
# **Most Matches Played by Venue**

# %%
venue_count = df['venue'].value_counts()
venue_count
# Out:
# venue
# Wankhede Stadium, Mumbai                        21
# Dr DY Patil Sports Academy, Mumbai              20
# Brabourne Stadium, Mumbai                       16
# Maharashtra Cricket Association Stadium,Pune    13
# Eden Gardens, Kolkata                            2
# Narendra Modi Stadium, Ahmedabad                 2
# Name: count, dtype: int64

# %%
sns.barplot(y = venue_count.index,x = venue_count.values,palette='rainbow')
# Out:
# /tmp/ipykernel_12930/1678963443.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y = venue_count.index,x = venue_count.values,palette='rainbow')
# <Axes: ylabel='venue'>

# %% [markdown]
# Custom Questions & Insights

# %% [markdown]
# **Q1: Who won the highest margin by runs?**

# %%
df.head(10)
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
# 5         6  March 30,2022            Dr DY Patil Sports Academy, Mumbai
# 6         7  March 31,2022                     Brabourne Stadium, Mumbai
# 7         8   April 1,2022                      Wankhede Stadium, Mumbai
# 8         9   April 2,2022            Dr DY Patil Sports Academy, Mumbai
# 9        10   April 2,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# ...

# %%
df[df['won_by'] == 'Runs'].sort_values(by='margin',ascending=False).head(1)[['match_winner','margin']]
# Out:
#    match_winner  margin
# 54      Chennai      91

# %% [markdown]
# **Q2: Which player had the highest individual score?**

# %%
df[df['highscore'] == df['highscore'].max()][['top_scorer','highscore']]
# Out:
#          top_scorer  highscore
# 65  Quinton de Kock        140

# %% [markdown]
# Q3: Which bowler had the best bowling figures? **bold text**

# %%
df[df['highest_wickets'] == df['highest_wickets'].max()][['best_bowling','best_bowling_figure']]
# Out:
#          best_bowling best_bowling_figure
# 29   Yuzvendra Chahal               5--40
# 39        Umran Malik               5--25
# 53  Wanindu Hasaranga               5--18
# 55     Jasprit Bumrah               5--10
