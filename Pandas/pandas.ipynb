# %% [markdown]
# <a href="https://colab.research.google.com/github/subhamsam007/Numpy-and-pandas/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Padas** **Series**\n
# *A Series is a one-dimensional labeled array capable of holding any data type. The axis labels are collectively called the index.*
#
# #**Creating Series**
# *There are multiple ways to create a pandas Series:*

# %%
import numpy as np
import pandas as pd

# %%
labels = ['a', 'b', 'c']
my_list = [10,20,30]
arr = np.array([10,20,30])
d = {'a':10,'b':20,'c':30}

# %% [markdown]
# # New Section
# all about series

# %%
pd.Series(my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# # Data frames

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
df2= pd.DataFrame(data_list, columns=['test', 'Age', 'City', 'Salary'])
df2
# Out:
#     test  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# selecting and indexing of colums

# %%
df2
# Out:
#     test  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2[['test','City','Age']]
# Out:
#     test      City  Age
# 0   John  New York   28
# 1   Anna     Paris   34
# 2  Peter    Berlin   29
# 3  Linda    London   42

# %% [markdown]
# # How to create a new coloum inside data frame

# %%
df2['new_data']=['doc','eng','gg','dfsd']
df2
# Out:
#     test  Age      City  Salary new_data
# 0   John   28  New York   65000      doc
# 1   Anna   34     Paris   70000      eng
# 2  Peter   29    Berlin   62000       gg
# 3  Linda   42    London   85000     dfsd

# %% [markdown]
# Remove a coloumms

# %%
df2.drop('new_data',axis=1,inplace=True)
df2
# Out:
#     test  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# selecting of rows

# %%
df2.loc[3] # only for selecting one coloum
# Out:
# test       Linda
# Age           42
# City      London
# Salary     85000
# Name: 3, dtype: object

# %%
df2.loc[[0,2]]
# Out:
#     test  Age      City  Salary
# 0   John   28  New York   65000
# 2  Peter   29    Berlin   62000

# %% [markdown]
# selecting the subset of  rows and columms

# %%
df2
# Out:
#     test  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.loc[[2,3]][["test","Age"]]
# Out:
#     test  Age
# 2  Peter   29
# 3  Linda   42

# %% [markdown]
# # condition selection

# %%
#want to see those above 18
df2[df2['Age']>30]
# Out:
#     test  Age    City  Salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %%
#want to see those above 18 and their salaries should be more than 70000
df2[(df2["Age"]>10) & (df2["Salary"]<70000)]
# Out:
#     test  Age      City  Salary
# 0   John   28  New York   65000
# 2  Peter   29    Berlin   62000

# %% [markdown]
# # MISSING DATA

# %% [markdown]
# finding mising  data

# %%
data = {
    'A': [1, 2, np.nan, 4, 5],
    'B': [1, 2, 3, 4, 5],
    'C': [1, 2, 3, np.nan, np.nan],
    'D': [1, np.nan, np.nan, np.nan, 5]
}
dtf=pd.DataFrame(data)
dtf
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
dtf.isna()
# Out:
#        A      B      C      D
# 0  False  False  False  False
# 1  False  False  False   True
# 2   True  False  False   True
# 3  False  False   True   True
# 4  False  False   True  False

# %%
dtf.isna().sum()
# Out:
# A    1
# B    0
# C    2
# D    3
# dtype: int64

# %%
dtf.isna().any()
# Out:
# A     True
# B    False
# C     True
# D     True
# dtype: bool

# %% [markdown]
# Now Removing The Missing Data

# %%
dtf
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
dtf.dropna()
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0

# %%
# the df.dropna(axis=0, thresh=3) would drop any row that has fewer than 3 non-null values.
dtf.dropna(axis=1, thresh=3)
# Out:
#      A  B    C
# 0  1.0  1  1.0
# 1  2.0  2  2.0
# 2  NaN  3  3.0
# 3  4.0  4  NaN
# 4  5.0  5  NaN

# %% [markdown]
# now filling the miing value

# %%
dtf.fillna(00)
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  0.0
# 2  0.0  3  3.0  0.0
# 3  4.0  4  0.0  0.0
# 4  5.0  5  0.0  5.0

# %%
values = {"A":10,"B":100,"C":200,"D":400}
dtf.fillna(value = values)
# Out:
#       A  B      C      D
# 0   1.0  1    1.0    1.0
# 1   2.0  2    2.0  400.0
# 2  10.0  3    3.0  400.0
# 3   4.0  4  200.0  400.0
# 4   5.0  5  200.0    5.0

# %% [markdown]
# # now merging, Joining ,concatinating dataframes

# %% [markdown]
# **merging 2 data frames**

# %%
employees = pd.DataFrame({
    'employee_id': [1, 2, 3, 4, 5],
    'name': ['John', 'Anna', 'Peter', 'Linda', 'Bob'],
    'department': ['HR', 'IT', 'Finance', 'IT', 'HR']
})

# DataFrame 2: Salary information
salaries = pd.DataFrame({
    'employee_id': [1, 2, 3, 6, 7],
    'salary': [60000, 80000, 65000, 70000, 90000],
    'bonus': [5000, 10000, 7000, 8000, 12000]
})

# %%
employees
# Out:
#    employee_id   name department
# 0            1   John         HR
# 1            2   Anna         IT
# 2            3  Peter    Finance
# 3            4  Linda         IT
# 4            5    Bob         HR

# %%
salaries
# Out:
#    employee_id  salary  bonus
# 0            1   60000   5000
# 1            2   80000  10000
# 2            3   65000   7000
# 3            6   70000   8000
# 4            7   90000  12000

# %%
#so now if we have to mearge then the same employee id the
pd.merge(employees,salaries,on='employee_id',how ='inner')
#
# Out:
#    employee_id   name department  salary  bonus
# 0            1   John         HR   60000   5000
# 1            2   Anna         IT   80000  10000
# 2            3  Peter    Finance   65000   7000

# %%
# now if we want to merge the whole id with the missing value as you can see in the output
pd.merge(employees,salaries,on='employee_id',how ='outer')
# Out:
#    employee_id   name department   salary    bonus
# 0            1   John         HR  60000.0   5000.0
# 1            2   Anna         IT  80000.0  10000.0
# 2            3  Peter    Finance  65000.0   7000.0
# 3            4  Linda         IT      NaN      NaN
# 4            5    Bob         HR      NaN      NaN
# 5            6    NaN        NaN  70000.0   8000.0
# 6            7    NaN        NaN  90000.0  12000.0

# %% [markdown]
# **contatination of 2 data frames**

# %%
df1 = pd.DataFrame({
    'A': ['A0', 'A1', 'A2'],
    'B': ['B0', 'B1', 'B2'],
    'C': ['C0', 'C1', 'C2']
})

df2 = pd.DataFrame({
    'A': ['A3', 'A4', 'A5'],
    'B': ['B3', 'B4', 'B5'],
    'C': ['C3', 'C4', 'C5']
})

# %%
df1
# Out:
#     A   B   C
# 0  A0  B0  C0
# 1  A1  B1  C1
# 2  A2  B2  C2

# %%
df2
# Out:
#     A   B   C
# 0  A3  B3  C3
# 1  A4  B4  C4
# 2  A5  B5  C5

# %%
#so concat( is the function name)
pd.concat([df1,df2])
# Out:
#     A   B   C
# 0  A0  B0  C0
# 1  A1  B1  C1
# 2  A2  B2  C2
# 0  A3  B3  C3
# 1  A4  B4  C4
# 2  A5  B5  C5

# %%
#so now if i want to give axis then
pd.concat([df1,df2],axis=1)
# Out:
#     A   B   C   A   B   C
# 0  A0  B0  C0  A3  B3  C3
# 1  A1  B1  C1  A4  B4  C4
# 2  A2  B2  C2  A5  B5  C5

# %% [markdown]
# **joining of 2 data frames**
#
# > Add blockquote

# %%
df1 = pd.DataFrame({
    'name': ['Alice', 'Bob', 'Charlie']
}, index=[1, 2, 3])

# Second DataFrame
df2 = pd.DataFrame({
    'score': [85, 90, 75]
}, index=[2, 3, 4])

# %%
df1.join(df2)
# Out:
#       name  score
# 1    Alice    NaN
# 2      Bob   85.0
# 3  Charlie   90.0

# %%
df2.join(df1)
# Out:
#    score     name
# 2     85      Bob
# 3     90  Charlie
# 4     75      NaN

# %%
df1.join(df2,how='outer')
# Out:
#       name  score
# 1    Alice    NaN
# 2      Bob   85.0
# 3  Charlie   90.0
# 4      NaN   75.0

# %% [markdown]
#  # group by aggregation

# %%
data = {
    'Category': ['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B'],
    'Store': ['S1', 'S1', 'S2', 'S2', 'S1', 'S2', 'S2', 'S1'],
    'Sales': [100, 200, 150, 250, 120, 180, 200, 300],
    'Quantity': [10, 15, 12, 18, 8, 20, 15, 25],
    'Date': pd.date_range('2023-01-01', periods=8)
}
df = pd.DataFrame(data)
df
# Out:
#   Category Store  Sales  Quantity       Date
# 0        A    S1    100        10 2023-01-01
# 1        B    S1    200        15 2023-01-02
# 2        A    S2    150        12 2023-01-03
# 3        B    S2    250        18 2023-01-04
# 4        A    S1    120         8 2023-01-05
# 5        B    S2    180        20 2023-01-06
# 6        A    S2    200        15 2023-01-07
# 7        B    S1    300        25 2023-01-08

# %%
cat=df.groupby('Category')['Sales'].sum()
cat
# Out:
# Category
# A    570
# B    930
# Name: Sales, dtype: int64

# %%
# group by multiple coloum and group by catagory and store
cat_store=df.groupby(['Category','Store'])['Sales'].sum()
cat_store
# Out:
# Category  Store
# A         S1       220
#           S2       350
# B         S1       500
#           S2       430
# Name: Sales, dtype: int64

# %% [markdown]
# # pivot tables

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}
df=pd.DataFrame(data )
# df['MOnth']=df['Date'].dt.month-name()

df['Month'] = df['Date'].dt.month_name()
df['quater'] = "Q" +df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month quater
# 0  2023-01-01       A   East    127     86   John  January     Q1
# 1  2023-01-02       B   West    443     48   Mary  January     Q1
# 2  2023-01-03       C  North    805     21    Bob  January     Q1
# 3  2023-01-04       D  South    840     68  Alice  January     Q1
# 4  2023-01-05       A   East    963     46   John  January     Q1
# 5  2023-01-06       B   West    853     33   Mary  January     Q1
# 6  2023-01-07       C  North    646     98    Bob  January     Q1
# 7  2023-01-08       D  South    464     60  Alice  January     Q1
# 8  2023-01-09       A   East    661     24   John  January     Q1
# 9  2023-01-10       B   West    912     82   Mary  January     Q1
# 10 2023-01-11       C  North    314     83    Bob  January     Q1
# 11 2023-01-12       D  South    825     99  Alice  January     Q1
# 12 2023-01-13       A   East    110     71   John  January     Q1
# ...

# %%
pd.pivot_table(df,index=['Product','Region'],values='Sales',aggfunc='sum')
# Out:
#                 Sales
# Product Region
# A       East     2777
# B       West     3315
# C       North    2246
# D       South    3509

# %% [markdown]
# # Data frames basic operations

# %%
df1 = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': [10, 20, 30, 40, 50],
    'C': [100, 200, 300, 400, 500]
})
df1.shape
# Out:
# (5, 3)

# %%
df1.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df1.describe()
# Out:
#               A          B           C
# count  5.000000   5.000000    5.000000
# mean   3.000000  30.000000  300.000000
# std    1.581139  15.811388  158.113883
# min    1.000000  10.000000  100.000000
# 25%    2.000000  20.000000  200.000000
# 50%    3.000000  30.000000  300.000000
# 75%    4.000000  40.000000  400.000000
# max    5.000000  50.000000  500.000000

# %% [markdown]
# ** data frames applying function**

# %%
df1['D'] = df1["B"].apply(lambda x : x**2)

# %%
df1
# Out:
#    A   B    C     D
# 0  1  10  100   100
# 1  2  20  200   400
# 2  3  30  300   900
# 3  4  40  400  1600
# 4  5  50  500  2500
